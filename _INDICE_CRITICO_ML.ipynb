# %% [markdown]
# <a href="https://colab.research.google.com/github/alberths-mx/About-me/blob/main/_INDICE_CRITICO_ML.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Introducción
# Mostramos una manera de descargar archivos en formato .csv del sistema * abiertos de la CDMX, desde línea de comando de Google Colab y convertirlo en un dataframe.

# %%
# !wget https://datos.cdmx.gob.mx/dataset/77641315-2613-4264-b534-0b4ed93fe6fd/resource/91e26301-c391-4df4-9478-1bc42a6ec9f9/download/censo_c_discapacidad.csv
# Out:
# --2023-12-05 05:44:09--  https://datos.cdmx.gob.mx/dataset/77641315-2613-4264-b534-0b4ed93fe6fd/resource/91e26301-c391-4df4-9478-1bc42a6ec9f9/download/censo_c_discapacidad.csv
# Resolving datos.cdmx.gob.mx (datos.cdmx.gob.mx)... 45.60.240.232
# Connecting to datos.cdmx.gob.mx (datos.cdmx.gob.mx)|45.60.240.232|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 6517 (6.4K) [application/octet-stream]
# Saving to: ‘censo_c_discapacidad.csv’
#
# censo_c_discapacida 100%[===================>]   6.36K  --.-KB/s    in 0s
#
# 2023-12-05 05:44:10 (46.6 MB/s) - ‘censo_c_discapacidad.csv’ saved [6517/6517]

# %%
import pandas
df = pandas.read_csv("/content/censo_c_discapacidad.csv")

# %%
df
# Out:
#                   alcaldia  pob_tot  pob_disc  pob_disc_mot  pob_disc_vis  \
# 0             AZCAPOTZALCO   432205     24000         12346          9965
# 1                 COYOACAN   614447     34446         17427         13897
# 2    CUAJIMALPA DE MORELOS   217686      7684          3416          3565
# 3        GUSTAVO A. MADERO  1173351     68712         35394         28584
# 4                IZTACALCO   404695     24447         12464         10229
# 5               IZTAPALAPA  1835486    104424         49556         47193
# 6   LA MAGDALENA CONTRERAS   247622     13859          6746          6073
# 7               MILPA ALTA   152685      7725          3470          3318
# 8           ALVARO OBREGON   759137     38175         19167         15942
# 9                  TLAHUAC   392313     20931          9736          9446
# 10                 TLALPAN   699928     35488         17195         14808
# 11              XOCHIMILCO   442178     23115         10703         10431
# ...

# %%
df.columns
# Out:
# Index(['alcaldia', 'pob_tot', 'pob_disc', 'pob_disc_mot', 'pob_disc_vis',
#        'pob_disc_len', 'pob_disc_aud', 'pob_disc_mot2', 'pob_disc_men',
#        'pob_lim', 'pob_lim_mot', 'pob_lim_vis', 'pob_lim_len', 'pob_lim_aud',
#        'pob_lim_mot2', 'pob_lim_rec', 'pob_lim_men', 't_pob_disc',
#        't_pob_disc_mot', 't_pob_disc_vis', 't_pob_disc_len', 't_pob_disc_aud',
#        't_pob_disc_mot2', 't_pob_disc_men', 't_pob_lim', 't_pob_lim_mot',
#        't_pob_lim_vis', 't_pob_lim_len', 't_pob_lim_aud', 't_pob_lim_mot2',
#        't_pob_lim_rec', 't_pob_lim_men'],
#       dtype='object')

# %%
alcaldia = df["alcaldia"]
alcaldia
# Out:
# 0               AZCAPOTZALCO
# 1                   COYOACAN
# 2      CUAJIMALPA DE MORELOS
# 3          GUSTAVO A. MADERO
# 4                  IZTACALCO
# 5                 IZTAPALAPA
# 6     LA MAGDALENA CONTRERAS
# 7                 MILPA ALTA
# 8             ALVARO OBREGON
# 9                    TLAHUAC
# 10                   TLALPAN
# 11                XOCHIMILCO
# 12             BENITO JUAREZ
# 13                CUAUHTEMOC
# 14            MIGUEL HIDALGO
# 15       VENUSTIANO CARRANZA
# Name: alcaldia, dtype: object

# %%
alcaldias = list(set(alcaldia))
alcaldia
# Out:
# 0               AZCAPOTZALCO
# 1                   COYOACAN
# 2      CUAJIMALPA DE MORELOS
# 3          GUSTAVO A. MADERO
# 4                  IZTACALCO
# 5                 IZTAPALAPA
# 6     LA MAGDALENA CONTRERAS
# 7                 MILPA ALTA
# 8             ALVARO OBREGON
# 9                    TLAHUAC
# 10                   TLALPAN
# 11                XOCHIMILCO
# 12             BENITO JUAREZ
# 13                CUAUHTEMOC
# 14            MIGUEL HIDALGO
# 15       VENUSTIANO CARRANZA
# Name: alcaldia, dtype: object

# %%
len(alcaldia)
# Out:
# 16

# %%
filtro = [
        'LA MAGDALENA CONTRERAS',

]

# %%
alcaldia_df = df[df["alcaldia"].isin(filtro)]
alcaldia_df
# Out:
#                  alcaldia  pob_tot  pob_disc  pob_disc_mot  pob_disc_vis  \
# 6  LA MAGDALENA CONTRERAS   247622     13859          6746          6073
#
#    pob_disc_len  pob_disc_aud  pob_disc_mot2  pob_disc_men  pob_lim  ...  \
# 6          1641          3110           2272          2307    33389  ...
#
#    t_pob_disc_mot2  t_pob_disc_men  t_pob_lim  t_pob_lim_mot  t_pob_lim_vis  \
# 6         0.917528        0.931662  13.483858       4.338064        8.68057
#
#    t_pob_lim_len  t_pob_lim_aud  t_pob_lim_mot2  t_pob_lim_rec  t_pob_lim_men
# 6       0.698646       2.865254        0.587589       2.808717       1.555597
#
# [1 rows x 32 columns]
